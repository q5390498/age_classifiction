# %%
import keras
from keras.models import load_model
import glob
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
model = load_model('age_rennet50_tuned.h5')

# %%
test_dir = '/root/sxwl-dataset/nas/luoyulong/incoming/custom/'
imgs_path = glob.glob(test_dir + "*.jpg")

for img_path in imgs_path:
    #print img_path
    im = cv2.imread(img_path)
    #print im
    print img_path
    im = cv2.resize(im, (224, 224))
    plt.imshow(im[:, :, ::-1])
    plt.figure(num=None,figsize=(5,5))
    plt.show()
# Out:
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/1.jpg
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/2.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/3.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/4.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/5.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/6.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/7.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/8.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/9.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/10.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/11.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/12.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/13.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/14.jpg
# <img src="data:image/png;base64,...">
# /root/sxwl-dataset/nas/luoyulong/incoming/custom/15.jpg
# <img src="data:image/png;base64,...">

# %%
imgs_path
# Out:
# ['/root/sxwl-dataset/nas/luoyulong/incoming/custom/1.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/2.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/3.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/4.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/5.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/6.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/7.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/8.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/9.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/10.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/11.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/12.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/13.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/14.jpg',
#  '/root/sxwl-dataset/nas/luoyulong/incoming/custom/15.jpg']
